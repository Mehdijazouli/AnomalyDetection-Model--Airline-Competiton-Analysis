# %%
import pandas as pd

df = pd.read_excel("03JUL.xlsx")
df
# Out:
#                        IMG                  Sem  Mkt Al   Route  Somme de Ops
# 0      2023-07-03 00:00:00  2023-07-03 00:00:00      TU  TUNDSS           1.0
# 1      2023-07-03 00:00:00  2023-07-03 00:00:00      TU  TUNFCO           6.0
# 2      2023-07-03 00:00:00  2023-07-03 00:00:00      TU  TUNFRA           7.0
# 3      2023-07-03 00:00:00  2023-07-03 00:00:00      TU  TUNGVA           8.0
# 4      2023-07-03 00:00:00  2023-07-03 00:00:00      TU  TUNIST          11.0
# ...                    ...                  ...     ...     ...           ...
# 51960  2023-07-03 00:00:00  2023-10-23 00:00:00      TU  TUNALG           2.0
# 51961  2023-07-03 00:00:00  2023-10-23 00:00:00      TU  TUNBLQ           1.0
# 51962  2023-07-03 00:00:00  2023-10-23 00:00:00      TU  TUNBRU           1.0
# 51963  2023-07-03 00:00:00  2023-10-23 00:00:00      TU  TUNCMN           1.0
# 51964               (vide)               (vide)  (vide)  (vide)           NaN
#
# [51965 rows x 5 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51965 entries, 0 to 51964
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   IMG           51965 non-null  object
#  1   Sem           51965 non-null  object
#  2   Mkt Al        51965 non-null  object
#  3   Route         51965 non-null  object
#  4   Somme de Ops  51964 non-null  float64
# dtypes: float64(1), object(4)
# memory usage: 2.0+ MB

# %%
df['Somme de Ops'] = df['Somme de Ops'].fillna(0).astype(int)

df.drop(columns='IMG', inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51965 entries, 0 to 51964
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Sem           51965 non-null  object
#  1   Mkt Al        51965 non-null  object
#  2   Route         51965 non-null  object
#  3   Somme de Ops  51965 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 1.6+ MB

# %%
df
# Out:
#                        Sem  Mkt Al   Route  Somme de Ops
# 0      2023-07-03 00:00:00      TU  TUNDSS             1
# 1      2023-07-03 00:00:00      TU  TUNFCO             6
# 2      2023-07-03 00:00:00      TU  TUNFRA             7
# 3      2023-07-03 00:00:00      TU  TUNGVA             8
# 4      2023-07-03 00:00:00      TU  TUNIST            11
# ...                    ...     ...     ...           ...
# 51960  2023-10-23 00:00:00      TU  TUNALG             2
# 51961  2023-10-23 00:00:00      TU  TUNBLQ             1
# 51962  2023-10-23 00:00:00      TU  TUNBRU             1
# 51963  2023-10-23 00:00:00      TU  TUNCMN             1
# 51964               (vide)  (vide)  (vide)             0
#
# [51965 rows x 4 columns]

# %%
df = df.dropna()
df = df.drop_duplicates()
df = df.loc[df['Somme de Ops'] != 0]
df
# Out:
#                        Sem Mkt Al   Route  Somme de Ops
# 0      2023-07-03 00:00:00     TU  TUNDSS             1
# 1      2023-07-03 00:00:00     TU  TUNFCO             6
# 2      2023-07-03 00:00:00     TU  TUNFRA             7
# 3      2023-07-03 00:00:00     TU  TUNGVA             8
# 4      2023-07-03 00:00:00     TU  TUNIST            11
# ...                    ...    ...     ...           ...
# 51959  2023-10-23 00:00:00     TU  TLSTUN             1
# 51960  2023-10-23 00:00:00     TU  TUNALG             2
# 51961  2023-10-23 00:00:00     TU  TUNBLQ             1
# 51962  2023-10-23 00:00:00     TU  TUNBRU             1
# 51963  2023-10-23 00:00:00     TU  TUNCMN             1
#
# [51963 rows x 4 columns]

# %%
cir = pd.read_excel("Cir.xlsx")
cir
# Out:
#        Route  Dep  Arr     Circuity
# 0     cmndoh  cmn  doh   100.000000
# 1     ABJACC  ABJ  ACC  1514.476811
# 2     ABJALG  ABJ  ALG   117.608663
# 3     ABJBKO  ABJ  BKO   593.130715
# 4     ABJBRU  ABJ  BRU   103.816644
# ...      ...  ...  ...          ...
# 1932  CMNTFS  CMN  TFS   100.000000
# 1933  BRUTNG  BRU  TNG   132.171723
# 1934  FEZORY  FEZ  ORY   122.396271
# 1935  DOHCMN  DOH  CMN   100.000000
# 1936  TFSCMN  TFS  CMN   100.000000
#
# [1937 rows x 4 columns]

# %%
cir = cir.dropna()
cir
# Out:
#        Route  Dep  Arr     Circuity
# 0     cmndoh  cmn  doh   100.000000
# 1     ABJACC  ABJ  ACC  1514.476811
# 2     ABJALG  ABJ  ALG   117.608663
# 3     ABJBKO  ABJ  BKO   593.130715
# 4     ABJBRU  ABJ  BRU   103.816644
# ...      ...  ...  ...          ...
# 1932  CMNTFS  CMN  TFS   100.000000
# 1933  BRUTNG  BRU  TNG   132.171723
# 1934  FEZORY  FEZ  ORY   122.396271
# 1935  DOHCMN  DOH  CMN   100.000000
# 1936  TFSCMN  TFS  CMN   100.000000
#
# [1937 rows x 4 columns]

# %%
df = pd.merge(df, cir, on='Route', how='inner')
df
# Out:
#                        Sem Mkt Al   Route  Somme de Ops  Dep  Arr    Circuity
# 0      2023-07-03 00:00:00     TU  TUNDSS             1  TUN  DSS  108.080709
# 1      2023-07-10 00:00:00     TU  TUNDSS             2  TUN  DSS  108.080709
# 2      2023-07-17 00:00:00     TU  TUNDSS             2  TUN  DSS  108.080709
# 3      2023-07-24 00:00:00     TU  TUNDSS             2  TUN  DSS  108.080709
# 4      2023-07-31 00:00:00     TU  TUNDSS             2  TUN  DSS  108.080709
# ...                    ...    ...     ...           ...  ...  ...         ...
# 51796  2023-10-16 00:00:00    TOM  LGWDSS             1  LGW  DSS  100.598576
# 51797  2023-10-23 00:00:00    TOM  LGWDSS             1  LGW  DSS  100.598576
# 51798  2023-10-09 00:00:00    TOM  DSSLGW             1  DSS  LGW  100.598576
# 51799  2023-10-16 00:00:00    TOM  DSSLGW             1  DSS  LGW  100.598576
# 51800  2023-10-23 00:00:00    TOM  DSSLGW             1  DSS  LGW  100.598576
#
# [51801 rows x 7 columns]

# %%
# Enregistrer le DataFrame en tant que fichier Excel
df.to_excel("route_circuity.xlsx", index=False)

# %%
import pandas as pd

df = pd.read_excel('route_circuity.xlsx')
df
# Out:
#              Sem Mkt Al   Route  Somme de Ops  Dep  Arr    Circuity
# 0     2023-07-03     TU  TUNDSS             1  TUN  DSS  108.080709
# 1     2023-07-10     TU  TUNDSS             2  TUN  DSS  108.080709
# 2     2023-07-17     TU  TUNDSS             2  TUN  DSS  108.080709
# 3     2023-07-24     TU  TUNDSS             2  TUN  DSS  108.080709
# 4     2023-07-31     TU  TUNDSS             2  TUN  DSS  108.080709
# ...          ...    ...     ...           ...  ...  ...         ...
# 51796 2023-10-16    TOM  LGWDSS             1  LGW  DSS  100.598576
# 51797 2023-10-23    TOM  LGWDSS             1  LGW  DSS  100.598576
# 51798 2023-10-09    TOM  DSSLGW             1  DSS  LGW  100.598576
# 51799 2023-10-16    TOM  DSSLGW             1  DSS  LGW  100.598576
# 51800 2023-10-23    TOM  DSSLGW             1  DSS  LGW  100.598576
#
# [51801 rows x 7 columns]

# %%
ville_mar = ["AGA" ,"CMN" ,"VIL" ,"ESU", "FEZ" ,"RAK" ,"NDR" ,"OZZ" ,"OUD" ,"RBA" ,"TNG"]

# %%
# Supprimer les lignes ne répondant pas aux critères
condition = ((df['Circuity'] >= 110) & (df['Circuity'] <= 130)) | ((df['Arr'].isin(ville_mar)) | (df['Dep'].isin(ville_mar)))
df = df[condition]
df = df[df['Mkt Al'] != 'AT']

# %%
df["Agence"] = df["Mkt Al"]
df["Route_base"] = df["Route"]
df
# Out:
#              Sem Mkt Al   Route  Somme de Ops  Dep  Arr    Circuity Agence  \
# 739   2023-07-03     U2  AGAGVA             2  AGA  GVA  100.124659     U2
# 740   2023-07-10     U2  AGAGVA             2  AGA  GVA  100.124659     U2
# 741   2023-07-17     U2  AGAGVA             2  AGA  GVA  100.124659     U2
# 742   2023-07-24     U2  AGAGVA             2  AGA  GVA  100.124659     U2
# 743   2023-07-31     U2  AGAGVA             2  AGA  GVA  100.124659     U2
# ...          ...    ...     ...           ...  ...  ...         ...    ...
# 51779 2023-09-18     4Y  RAKFRA             3  RAK  FRA  100.389127     4Y
# 51780 2023-09-25     4Y  RAKFRA             3  RAK  FRA  100.389127     4Y
# 51781 2023-10-02     4Y  RAKFRA             4  RAK  FRA  100.389127     4Y
# 51782 2023-10-09     4Y  RAKFRA             7  RAK  FRA  100.389127     4Y
# 51783 2023-10-16     4Y  RAKFRA             7  RAK  FRA  100.389127     4Y
#
#       Route_base
# 739       AGAGVA
# 740       AGAGVA
# ...

# %%
from sklearn.ensemble import IsolationForest
from sklearn.preprocessing import LabelEncoder

df["Agence"] = df["Mkt Al"]
df["Route_base"] = df["Route"]

label_encoder = LabelEncoder()
df["Mkt Al"] = label_encoder.fit_transform(df["Mkt Al"])
df["Route"] = label_encoder.fit_transform(df["Route"])

# Sélectionner les colonnes pertinentes
columns = ["Somme de Ops", "Mkt Al", "Route"]

# Créer et entraîner le modèle Isolation Forest Extended
model = IsolationForest(contamination=0.05, random_state=42, bootstrap=True)
model.fit(df[columns])

# Prédire les anomalies
df["Anomalies"] = model.predict(df[columns])

# Les valeurs de "Somme de Ops" considérées comme anomalies sont celles où "Anomalies" est égal à -1
anomalies = df[df["Anomalies"] == -1]
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(

# %%
import joblib

# Supposons que 'label_encoder' est votre encodeur d'étiquettes
joblib.dump(label_encoder, 'label_encoder_mehdi.pkl')
# Out:
# ['label_encoder_mehdi.pkl']

# %%
anomalies
# Out:
#              Sem  Mkt Al  Route  Somme de Ops  Dep  Arr    Circuity Agence  \
# 2571  2023-07-03       5     91            19  CDG  RAK  100.144980     AF
# 2579  2023-08-28       5     91            18  CDG  RAK  100.144980     AF
# 2580  2023-09-04       5     91            18  CDG  RAK  100.144980     AF
# 2581  2023-09-11       5     91            18  CDG  RAK  100.144980     AF
# 2583  2023-09-18       5     91            18  CDG  RAK  100.144980     AF
# ...          ...     ...    ...           ...  ...  ...         ...    ...
# 49920 2023-09-25      32    193            27  JFK  IST  113.358294     TK
# 49921 2023-10-02      32    193            27  JFK  IST  113.358294     TK
# 49922 2023-10-09      32    193            27  JFK  IST  113.358294     TK
# 49923 2023-10-16      32    193            27  JFK  IST  113.358294     TK
# 51338 2023-10-23      37      4             1  ABJ  TUN  126.740140     TU
#
#       Route_base  Anomalies
# 2571      CDGRAK         -1
# ...

# %%
# Enregistrer le DataFrame en tant que fichier Excel
anomalies.to_excel("anomalies.xlsx", index=False)

# %%
import joblib
joblib.dump(model, 'isolation_stage_mehdi.pkl')
# Out:
# ['isolation_stage_mehdi.pkl']

# %%
df = pd.read_excel("10JUL.xlsx")
df['Somme de Ops'] = df['Somme de Ops'].fillna(0).astype(int)
df.drop(columns='IMG', inplace=True)
df = df.dropna()
df = df.drop_duplicates()
df = df.loc[df['Somme de Ops'] != 0]
df = pd.merge(df, cir, on='Route', how='inner')
condition = ((df['Circuity'] >= 110) & (df['Circuity'] <= 130)) | ((df['Arr'].isin(ville_mar)) | (df['Dep'].isin(ville_mar)))
df = df[condition]
df["Agence"] = df["Mkt Al"]
df["Route_base"] = df["Route"]
df = df[df['Mkt Al'] != 'AT']

df["Mkt Al"] = label_encoder.fit_transform(df["Mkt Al"])
df["Route"] = label_encoder.fit_transform(df["Route"])

columns = ["Somme de Ops", "Mkt Al", "Route"]
df["Anomalies"] = model.predict(df[columns])
anomalies = df[df["Anomalies"] == -1]
anomalies
# Out:
#              Sem  Mkt Al  Route  Somme de Ops  Dep  Arr    Circuity Agence  \
# 1567  2023-10-30      38     11             1  AGA  LGW  100.328291     U2
# 3375  2023-08-28       5     91            18  CDG  RAK  100.144980     AF
# 3376  2023-09-04       5     91            18  CDG  RAK  100.144980     AF
# 3377  2023-09-11       5     91            18  CDG  RAK  100.144980     AF
# 3379  2023-09-18       5     91            18  CDG  RAK  100.144980     AF
# ...          ...     ...    ...           ...  ...  ...         ...    ...
# 49948 2023-10-02      32    193            27  JFK  IST  113.358294     TK
# 49949 2023-10-09      32    193            27  JFK  IST  113.358294     TK
# 49950 2023-10-16      32    193            27  JFK  IST  113.358294     TK
# 49951 2023-10-23      32    193            26  JFK  IST  113.358294     TK
# 51368 2023-10-30      37      4             1  ABJ  TUN  126.740140     TU
#
#       Route_base  Anomalies
# 1567      AGALGW         -1
# ...

# %%
import matplotlib.pyplot as plt

# Séparez les points normaux et les anomalies
normaux = df[df['Anomalies'] != -1]
plt.figure(figsize=(24, 12))

# Créez un nuage de points avec des couleurs différentes pour les anomalies
plt.scatter(normaux['Agence'], normaux['Somme de Ops'], label='Points normaux', color='blue')
plt.scatter(anomalies['Agence'], anomalies['Somme de Ops'], label='Anomalies', color='red')

# Ajoutez des étiquettes et un titre

plt.xlabel('Agences')
plt.ylabel('Somme de Ops')
plt.title('Nuage de points avec anomalies')
plt.xticks(rotation=90)

# Affichez la légende
plt.legend()

# Affichez le nuage de points
plt.show()

# %%
# Séparez les points normaux et les anomalies
normaux = df[df['Anomalies'] != -1]

# Comptez le nombre de points aux mêmes coordonnées
coord_counts = normaux.groupby(['Agence', 'Somme de Ops']).size().reset_index(name='count')

# Créez un nuage de points avec des couleurs différentes pour les anomalies
plt.figure(figsize=(24, 12))
plt.scatter(normaux['Agence'], normaux['Somme de Ops'], label='Points normaux', color='blue', alpha=0.7)
plt.scatter(anomalies['Agence'], anomalies['Somme de Ops'], label='Anomalies', color='red', alpha=0.7)

# Ajoutez des étiquettes de texte indiquant le nombre de points aux mêmes coordonnées
for i, row in coord_counts.iterrows():
    plt.text(row['Agence'], row['Somme de Ops'], str(row['count']), ha='center', va='bottom')

# Ajoutez des étiquettes et un titre
plt.xlabel('Agences')
plt.ylabel('Somme de Ops')
plt.title('Nuage de points avec anomalies')

# Affichez la légende
plt.legend()

# Affichez le nuage de points
plt.savefig('ma_figure.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# Séparez les points normaux et les anomalies
normaux = df[df['Anomalies'] != -1]
plt.figure(figsize=(24, 12))

# Créez un nuage de points avec des couleurs différentes pour les anomalies
plt.scatter(normaux['Agence'], normaux['Route_base'], label='Points normaux', color='blue')
plt.scatter(anomalies['Agence'], anomalies['Route_base'], label='Anomalies', color='red')

# Ajoutez des étiquettes et un titre

plt.xlabel('Agences')
plt.ylabel('Routes')
plt.title('Nuage de points avec anomalies')
plt.xticks(rotation=90)

# Affichez la légende
plt.legend()

# Affichez le nuage de points
plt.show()
